# %%
import requests
from IPython.core.display import HTML
HTML(f"""
<style>
@import "https://cdn.jsdelivr.net/npm/bulma@0.9.4/css/bulma.min.css";
</style>
""")

# %% [markdown]
# # Linear Transformations
# This week's exercises introduce linear transformations and their implementation in Python.
# <article class="message is-success">
#   <div class="message-header">Learning goals</div>
#   <div class="message-body">
#
#   After this week's exercises, you should be able to:
# - Identify and reason about model parameters in a polynomial model.
# - Construct a design matrix.
# - Learn parameters for a polynomial model
# - Use the polynomial model to make predictions.
# - Visualize the predictions and reason about the performance of the model.
# - **Notice that this week contains a mandatory exercise (look for the star in the header of each task, as shown below)**
#
#
#
#   </div>
# </article>
#
# <div style="float: center; width: 100%; justify-content: start" class="block is-clearfix">
#
# <div class="has-text-centered">
# <figure class="image is-inline-block" >
#
# <img src="data:image/png;base64,..." class="figure-img img-fluid rounded" style="width:900px" />
#
#
# </figure>
# </div>
#
#
# </div>
